# %% [markdown]
# # Code Duplication

# %%
# !py -3.12 .\run_jscpd.py install
# Out:
# up to date, audited 121 packages in 1s
#
# 18 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# !py -3.12 .\run_jscpd.py run --repo "..\cJSON"
# Out:
# Clone found (c):
#  - tests\unity\examples\example_2\test\TestProductionCode.c [22:91 - 32:5] (10 lines, 86 tokens)
#    tests\unity\examples\example_3\test\TestProductionCode.c [20:5 - 30:5]
#
# Clone found (c):
#  - tests\unity\examples\example_2\src\ProductionCode.c [4:1 - 24:2] (20 lines, 165 tokens)
#    tests\unity\examples\example_3\src\ProductionCode.c [4:1 - 24:2]
#
# Clone found (c):
#  - tests\unity\examples\example_1\test\TestProductionCode.c [23:3 - 32:57] (9 lines, 87 tokens)
#    tests\unity\examples\example_3\test\TestProductionCode.c [23:3 - 32:54]
#
# Clone found (c):
#  - tests\unity\test\testdata\testRunnerGeneratorSmall.c [14:1 - 43:5] (29 lines, 166 tokens)
#    tests\unity\test\testdata\testRunnerGeneratorWithMocks.c [23:1 - 57:3]
#
# Clone found (c):
#  - tests\unity\test\testdata\testRunnerGenerator.c [1:1 - 181:2] (180 lines, 892 tokens)
#    tests\unity\test\testdata\testRunnerGeneratorWithMocks.c [1:1 - 182:2]
#
# Clone found (c):
# ...
