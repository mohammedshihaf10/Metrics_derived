# %% [markdown]
# # Code Churn

# %%
# !py -3.12 .\run_pydriller.py install
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: D:\Projects\Metrics_derived\c\Code Churn\tools\pydriller\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !py -3.12 .\run_pydriller.py run --repo "..\cJSON"
# Out:
# {
#   "summary": {
#     "total_commits": 1109,
#     "total_files_touched": 250,
#     "total_file_modifications": 1785
#   },
#   "top_files": [
#     {
#       "path": "cJSON.c",
#       "commit_count": 444,
#       "added_lines": 8160,
#       "deleted_lines": 4457,
#       "total_churn": 12617,
#       "last_commit": "5cc0e39f42dfe28cb8541f95fa2c513f0d550210"
#     },
#     {
#       "path": "cJSON_Utils.c",
#       "commit_count": 144,
#       "added_lines": 2773,
#       "deleted_lines": 1297,
#       "total_churn": 4070,
#       "last_commit": "74e1ff4994aa4139126967f6d289b675b4b36fef"
#     },
#     {
#       "path": "CMakeLists.txt",
#       "commit_count": 143,
#       "added_lines": 624,
#       "deleted_lines": 345,
#       "total_churn": 969,
#       "last_commit": "a29814f285cc531c00223743ad3c55cd38c0dc56"
#     },
#     {
#       "path": "cJSON.h",
#       "commit_count": 142,
#       "added_lines": 788,
#       "deleted_lines": 355,
#       "total_churn": 1143,
# ...
