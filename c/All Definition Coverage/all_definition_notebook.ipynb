# %% [markdown]
# # All Definition Coverage

# %%
# !py -3.12 .\run_all_definition.py install

# %%
# !py -3.12 .\run_all_definition.py run --repo "..\cJSON"
# Out:
# {
#   "definitions_total": 1015,
#   "definitions_covered": 931,
#   "definitions_with_covered_use": 839,
#   "definition_use_pairs_total": 6428,
#   "definition_use_pairs": [
#     {
#       "name": "i",
#       "def_line": 313,
#       "use_line": 325
#     },
#     {
#       "name": "i",
#       "def_line": 313,
#       "use_line": 327
#     },
#     {
#       "name": "i",
#       "def_line": 313,
#       "use_line": 368
#     },
#     {
#       "name": "i",
#       "def_line": 313,
#       "use_line": 370
#     },
#     {
#       "name": "i",
#       "def_line": 313,
#       "use_line": 373
#     },
#     {
#       "name": "allocation_length",
#       "def_line": 834,
#       "use_line": 857
#     },
#     {
#       "name": "allocation_length",
#       "def_line": 834,
#       "use_line": 858
#     },
#     {
#       "name": "number_c_string",
#       "def_line": 311,
#       "use_line": 357
#     },
#     {
#       "name": "number_c_string",
#       "def_line": 311,
# ...
