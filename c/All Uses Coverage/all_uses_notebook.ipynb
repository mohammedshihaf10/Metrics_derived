# %% [markdown]
# # All Uses Coverage

# %%
# !py -3.12 .\run_all_uses.py install

# %%
# !py -3.12 .\run_all_uses.py run --repo "..\cJSON"
# Out:
# {
#   "definitions_total": 1013,
#   "definition_use_pairs_total": 6282,
#   "covered_definition_use_pairs": 6282,
#   "c_use_pairs": 4352,
#   "p_use_pairs": 1930,
#   "definition_use_pairs": [
#     {
#       "name": "length",
#       "def_line": 595,
#       "use_line": 609,
#       "use_kind": "c-use"
#     },
#     {
#       "name": "length",
#       "def_line": 595,
#       "use_line": 613,
#       "use_kind": "c-use"
#     },
#     {
#       "name": "length",
#       "def_line": 595,
#       "use_line": 618,
#       "use_kind": "c-use"
#     },
#     {
#       "name": "length",
#       "def_line": 595,
#       "use_line": 624,
#       "use_kind": "c-use"
#     },
#     {
#       "name": "length",
#       "def_line": 595,
#       "use_line": 629,
#       "use_kind": "p-use"
#     },
#     {
#       "name": "length",
#       "def_line": 595,
#       "use_line": 635,
#       "use_kind": "c-use"
#     },
#     {
#       "name": "length",
#       "def_line": 595,
# ...
