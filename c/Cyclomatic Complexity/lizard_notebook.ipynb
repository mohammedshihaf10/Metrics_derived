# %% [markdown]
# # Cyclomatic Complexity

# %%
# !py -3.12 .\run_lizard.py install
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: D:\Projects\Metrics_derived\c\Cyclomatic Complexity\tools\lizard\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !py -3.12 .\run_lizard.py run --repo "..\cJSON" -- .
# Out:
# ...
#   NLOC    CCN   token  PARAM  length  location
# ------------------------------------------------
#        1      1      5      0       1 main@902-902@.\build-branch\CMakeFiles\4.2.3\CompilerIdC\CMakeCCompilerId.c
#       16      6     95      1      27 main@907-933@.\build-branch\CMakeFiles\4.2.3\CompilerIdC\CMakeCCompilerId.c
#       44      8    202      1      55 read_file@29-83@.\fuzzing\afl.c
#       78     19    339      2      92 main@85-176@.\fuzzing\afl.c
#       46     21    333      2      60 LLVMFuzzerTestOneInput@13-72@.\fuzzing\cjson_read_fuzzer.c
#       36      6    196      2      46 main@9-54@.\fuzzing\fuzz_main.c
#        7      1     55      0       7 initialize@23-29@.\tests\unity\auto\colour_prompt.rb
#        7      2     39      1       7 change_to@31-37@.\tests\unity\auto\colour_prompt.rb
#       21     17     85      1      21 win32_colour@39-59@.\tests\unity\auto\colour_prompt.rb
# ...
