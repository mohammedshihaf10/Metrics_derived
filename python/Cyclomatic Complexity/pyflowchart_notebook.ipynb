# %% [markdown]
# # pyflowchart Tool Runner
#
# This notebook uses the existing `run_pyflowchart.py` script.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
RUNNER = ROOT / "run_pyflowchart.py"
TARGET = ROOT / "tool_examples" / "logic_examples.py"

def run_command(args):
    result = subprocess.run(
        args,
        cwd=ROOT,
        capture_output=True,
        text=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr, file=sys.stderr)
    if result.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")
    return result.returncode

print(f"Runner: {RUNNER}")
print(f"Target file: {TARGET}")

# %% [markdown]
# ## Install pyflowchart

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "install",
])

# %% [markdown]
# ## Run pyflowchart

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(ROOT),
    "--",
    str(TARGET),
])
# Out:
# op2=>operation: 'Pure Python examples for CFG, path, and condition-oriented tools.'
# st5=>start: start route_order
# io7=>inputoutput: input: total, member, express
# op10=>operation: 'Pick a delivery path based on order size and flags.'
# cond13=>condition: if (total > 100)
# cond18=>condition: if (member or express)
# io25=>inputoutput: output:  'priority'
# e23=>end: end function return
# io34=>inputoutput: output:  'standard'
# e32=>end: end function return
# cond41=>condition: if (member and express)
# io48=>inputoutput: output:  'priority'
# e46=>end: end function return
# io57=>inputoutput: output:  'economy'
# e55=>end: end function return
#
# op2->st5
# st5->io7
# io7->op10
# op10->cond13
# cond13(yes)->cond18
# cond18(yes)->io25
# io25->e23
# cond18(no)->io34
# io34->e32
# cond13(no)->cond41
# cond41(yes)->io48
# io48->e46
# cond41(no)->io57
# io57->e55

# %%
from pathlib import Path
report = Path(r'requirements-whitebox.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# -r tools/coveragepy/requirements.txt
