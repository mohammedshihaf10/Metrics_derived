# %% [markdown]
# # CrossHair Tool Runner
#
# This notebook uses the existing `run_crosshair.py` script.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
RUNNER = ROOT / "run_crosshair.py"
TARGET = "tool_examples.logic_examples.route_order"

def run_command(args):
    result = subprocess.run(
        args,
        cwd=ROOT,
        capture_output=True,
        text=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr, file=sys.stderr)
    if result.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")
    return result.returncode

print(f"Runner: {RUNNER}")
print(f"Target: {TARGET}")

# %% [markdown]
# ## Install CrossHair

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "install",
])

# %% [markdown]
# ## Run CrossHair Cover

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(ROOT),
    "--",
    "cover",
    TARGET,
])
# Out:
# route_order(0, True, True)
# route_order(101, False, True)
# route_order(0, True, False)
# route_order(101, False, False)

# %%
from pathlib import Path
report = Path(r'requirements-whitebox.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# -r tools/coveragepy/requirements.txt
