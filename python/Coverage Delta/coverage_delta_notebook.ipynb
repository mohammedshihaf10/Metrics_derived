# %% [markdown]
# # Coverage Delta
#
# Runs `diff-cover` on the shared Python repo.

# %%
# !py -3.12 .\run_diff_cover.py install
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: D:\Projects\Metrics_derived\python\Coverage Delta\tools\diff-cover\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !py -3.12 .\run_diff_cover.py run --repo "..\Cyclomatic Complexity\github-actions-cicd-example" -- --compare-branch=HEAD~1
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.2, pluggy-1.6.0
# rootdir: D:\Projects\Metrics_derived\python\Cyclomatic Complexity\github-actions-cicd-example
# configfile: pyproject.toml
# collected 2 items
#
# tests\test_somecode.py ..                                                [100%]
#
# ============================== 2 passed in 0.40s ==============================
# Wrote XML report to coverage_delta.xml
