# %% [markdown]
# # coverage.py Statement Coverage

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd()
RUNNER = ROOT / 'run_coveragepy.py'
REPO = ROOT.parent / 'Cyclomatic Complexity' / 'github-actions-cicd-example'

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\Statement Coverage\\run_coveragepy.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'erase'], cwd=ROOT, check=True)
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'run', '-m', 'pytest'], cwd=ROOT, check=True)
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'json', '-o', 'coverage_statement.json'], cwd=ROOT, check=True)
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'report'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\Statement Coverage\\run_coveragepy.py', 'run', '--repo', 'd:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\github-actions-cicd-example', '--', 'report'], returncode=0)

# %%
import json
print(json.loads((REPO / 'coverage_statement.json').read_text(encoding='utf-8'))['totals'])
# Out:
# {'covered_lines': 20, 'num_statements': 21, 'percent_covered': 95.23809523809524, 'percent_covered_display': '95', 'missing_lines': 1, 'excluded_lines': 0, 'percent_statements_covered': 95.23809523809524, 'percent_statements_covered_display': '95'}

# %%
print((REPO / 'coverage_statement.json').read_text(encoding='utf-8', errors='ignore'))
# Out:
# {"meta": {"format": 3, "version": "7.13.4", "timestamp": "2026-03-12T19:56:59.190077", "branch_coverage": false, "show_contexts": false}, "files": {"actionscicd\\__init__.py": {"executed_lines": [5, 7, 9], "summary": {"covered_lines": 3, "num_statements": 3, "percent_covered": 100.0, "percent_covered_display": "100", "missing_lines": 0, "excluded_lines": 0, "percent_statements_covered": 100.0, "percent_statements_covered_display": "100"}, "missing_lines": [], "excluded_lines": [], "functions": {"": {"executed_lines": [5, 7, 9], "summary": {"covered_lines": 3, "num_statements": 3, "percent_covered": 100.0, "percent_covered_display": "100", "missing_lines": 0, "excluded_lines": 0, "percent_statements_covered": 100.0, "percent_statements_covered_display": "100"}, "missing_lines": [], "excluded_lines": [], "start_line": 1}}, "classes": {"": {"executed_lines": [5, 7, 9], "summary": {"covered_lines": 3, "num_statements": 3, "percent_covered": 100.0, "percent_covered_display": "100", "missi
# ...
