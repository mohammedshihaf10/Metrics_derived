# %% [markdown]
# # All Definition Coverage
#
# Runs `coverage.py + beniget` style def-use analysis on the shared Python repo.

# %%
# !py -3.12 .\run_defuse_combo.py install
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: D:\Projects\Metrics_derived\python\All Definition Coverage\tools\defuse-combo\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !py -3.12 .\run_defuse_combo.py run --repo "..\Cyclomatic Complexity\github-actions-cicd-example"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.2, pluggy-1.6.0
# rootdir: D:\Projects\Metrics_derived\python\Cyclomatic Complexity\github-actions-cicd-example
# configfile: pyproject.toml
# collected 2 items
#
# tests\test_somecode.py ..                                                [100%]
#
# ============================== 2 passed in 0.45s ==============================
# Wrote JSON report to defuse_coverage.json
# {
#   "file": "D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\github-actions-cicd-example\\actionscicd\\somecode.py",
#   "covered_lines": [
#     4,
#     5,
#     6,
#     9,
#     12,
#     15,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27,
#     29,
#     32
#   ],
#   "missing_lines": [
#     35
#   ],
#   "definitions_total": 9,
#   "definitions_covered": 9,
#   "definitions_with_covered_use": 9,
#   "definitions": [
#     {
# ...

# %%
from pathlib import Path
report = Path(r'all_definition_report.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# {
#   "file": "D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\github-actions-cicd-example\\actionscicd\\somecode.py",
#   "covered_lines": [
#     4,
#     5,
#     6,
#     9,
#     12,
#     15,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27,
#     29,
#     32
#   ],
#   "missing_lines": [
#     35
#   ],
#   "definitions_total": 9,
#   "definitions_covered": 9,
#   "definitions_with_covered_use": 9,
#   "definitions": [
#     {
#       "name": "arr1",
#       "lineno": 9,
#       "scope": "add_arrays",
#       "covered": true
#     },
#     {
#       "name": "arr2",
#       "lineno": 9,
#       "scope": "add_arrays",
#       "covered": true
#     },
#     {
#       "name": "filename",
#       "lineno": 15,
#       "scope": "load_datafile",
#       "covered": true
#     },
#     {
#       "name": "names",
#       "lineno": 18,
#       "scope": "load_datafile",
#       "covered": true
#     },
#     {
#       "name": "ages",
# ...
