# %% [markdown]
# # All Uses Coverage
#
# Runs `coverage.py + beniget` style def-use analysis on the shared Python repo.

# %%
# !py -3.12 .\run_defuse_combo.py install
# Out:
# Requirement already satisfied: coverage in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 1)) (7.13.4)
# Requirement already satisfied: pytest in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 2)) (9.0.2)
# Requirement already satisfied: numpy in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 3)) (2.4.3)
# Requirement already satisfied: beniget in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 4)) (0.5.0)
# Requirement already satisfied: gast in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: colorama>=0.4 in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from pytest->-r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from pytest->-r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: packaging>=22 in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from pytest->-r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from pytest->-r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in d:\projects\metrics_derived\python\all uses coverage\tools\defuse-combo\.venv\lib\site-packages (from pytest->-r D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\requirements.txt (line 2)) (2.19.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: D:\Projects\Metrics_derived\python\All Uses Coverage\tools\defuse-combo\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !py -3.12 .\run_defuse_combo.py run --repo "..\Cyclomatic Complexity\github-actions-cicd-example"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.2, pluggy-1.6.0
# rootdir: D:\Projects\Metrics_derived\python\Cyclomatic Complexity\github-actions-cicd-example
# configfile: pyproject.toml
# collected 2 items
#
# tests\test_somecode.py ..                                                [100%]
#
# ============================== 2 passed in 0.45s ==============================
# Wrote JSON report to defuse_coverage.json
# {
#   "file": "D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\github-actions-cicd-example\\actionscicd\\somecode.py",
#   "covered_lines": [
#     4,
#     5,
#     6,
#     9,
#     12,
#     15,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27,
#     29,
#     32
#   ],
#   "missing_lines": [
#     35
#   ],
#   "definitions_total": 9,
#   "uses_total": 28,
#   "definition_use_pairs_total": 12,
#   "covered_definition_use_pairs": 12,
#   "c_use_pairs": 10,
#   "p_use_pairs": 2,
#   "definition_use_pairs": [
#     {
#       "scope": "add_arrays",
#       "name": "arr1",
#       "def_line": 9,
#       "use_line": 12,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "add_arrays",
#       "name": "arr2",
#       "def_line": 9,
#       "use_line": 12,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "filename",
#       "def_line": 15,
#       "use_line": 21,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "file",
#       "def_line": 21,
#       "use_line": 22,
#       "use_kind": "p-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "idx",
#       "def_line": 22,
#       "use_line": 23,
#       "use_kind": "p-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "line",
#       "def_line": 22,
#       "use_line": 25,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "names",
#       "def_line": 18,
#       "use_line": 26,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "lineentries",
#       "def_line": 25,
#       "use_line": 26,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "ages",
#       "def_line": 19,
#       "use_line": 27,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "lineentries",
#       "def_line": 25,
#       "use_line": 27,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "names",
#       "def_line": 18,
#       "use_line": 29,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "ages",
#       "def_line": 19,
#       "use_line": 29,
#       "use_kind": "c-use",
#       "covered_pair": true
#     }
#   ],
#   "uncovered_definition_use_pairs": []
# }

# %%
from pathlib import Path
report = Path(r'all_uses_report.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# {
#   "file": "D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\github-actions-cicd-example\\actionscicd\\somecode.py",
#   "covered_lines": [
#     4,
#     5,
#     6,
#     9,
#     12,
#     15,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27,
#     29,
#     32
#   ],
#   "missing_lines": [
#     35
#   ],
#   "definitions_total": 9,
#   "uses_total": 28,
#   "definition_use_pairs_total": 12,
#   "covered_definition_use_pairs": 12,
#   "c_use_pairs": 10,
#   "p_use_pairs": 2,
#   "definition_use_pairs": [
#     {
#       "scope": "add_arrays",
#       "name": "arr1",
#       "def_line": 9,
#       "use_line": 12,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "add_arrays",
#       "name": "arr2",
#       "def_line": 9,
#       "use_line": 12,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "filename",
#       "def_line": 15,
#       "use_line": 21,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "file",
#       "def_line": 21,
#       "use_line": 22,
#       "use_kind": "p-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "idx",
#       "def_line": 22,
#       "use_line": 23,
#       "use_kind": "p-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "line",
#       "def_line": 22,
#       "use_line": 25,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "names",
#       "def_line": 18,
#       "use_line": 26,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "lineentries",
#       "def_line": 25,
#       "use_line": 26,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "ages",
#       "def_line": 19,
#       "use_line": 27,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "lineentries",
#       "def_line": 25,
#       "use_line": 27,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "names",
#       "def_line": 18,
#       "use_line": 29,
#       "use_kind": "c-use",
#       "covered_pair": true
#     },
#     {
#       "scope": "load_datafile",
#       "name": "ages",
#       "def_line": 19,
#       "use_line": 29,
#       "use_kind": "c-use",
#       "covered_pair": true
#     }
#   ],
#   "uncovered_definition_use_pairs": []
# }
