# %% [markdown]
# # cosmic-ray Mutation Score

# %%
from pathlib import Path
import subprocess, sys
ROOT=Path.cwd()
RUNNER=ROOT/'run_mutmut.py'
REPO=ROOT.parent/'Cyclomatic Complexity'/'github-actions-cicd-example'

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\Mutation Score\\run_mutmut.py', 'install'], returncode=0)

# %%
result = subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO)], cwd=ROOT)
print(f'cosmic-ray exit code: {result.returncode}')
# Out:
# cosmic-ray exit code: 1
