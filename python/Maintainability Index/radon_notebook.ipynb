# %% [markdown]
# # Radon Tool Runner
#
# This notebook runs the Python-only Maintainability Index setup using `run_radon.py`.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
RUNNER = ROOT / "run_radon.py"
DEFAULT_REPO = ROOT.parent / "github-actions-cicd-example"

def run_command(args):
    result = subprocess.run(
        args,
        cwd=ROOT,
        capture_output=True,
        text=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr, file=sys.stderr)
    if result.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")
    return result.returncode

print(f"Runner: {RUNNER}")
print(f"Default repo: {DEFAULT_REPO}")
# Out:
# Runner: d:\Projects\Metrics_derived\python\Maintainability Index\run_radon.py
# Default repo: d:\Projects\Metrics_derived\python\github-actions-cicd-example

# %% [markdown]
# ## Install Radon
#
# Runs the isolated radon install flow in `tools/radon`.

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "install",
])
# Out:
# 0

# %% [markdown]
# ## Configure Target Repo
#
# Change `repo_path` only when you want to point radon at a different repository.

# %%
repo_path = DEFAULT_REPO
repo_path
# Out:
# WindowsPath('d:/Projects/Metrics_derived/python/github-actions-cicd-example')

# %% [markdown]
# ## Run Radon Commands

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(repo_path),
    "--",
    "cc",
    ".",
    "-s",
])
# Out:
# 0

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(repo_path),
    "--",
    "mi",
    ".",
])
# Out:
# 0

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(repo_path),
    "--",
    "raw",
    ".",
])
# Out:
# 0

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(repo_path),
    "--",
    "hal",
    ".",
])
# Out:
# 0

# %%
from pathlib import Path
report = Path(r'requirements-whitebox.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# -r tools/coveragepy/requirements.txt
