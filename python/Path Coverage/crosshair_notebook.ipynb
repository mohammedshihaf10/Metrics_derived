# %% [markdown]
# # CrossHair Path Coverage

# %%
from pathlib import Path
import subprocess, sys
ROOT=Path.cwd()
RUNNER=ROOT/'run_crosshair.py'
REPO=ROOT.parent/'Cyclomatic Complexity'

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'cover', 'tool_examples.logic_examples.route_order'], cwd=ROOT, check=True)
# Out:
# route_order(0, True, True)
# route_order(101, False, True)
# route_order(0, True, False)
# route_order(101, False, False)
