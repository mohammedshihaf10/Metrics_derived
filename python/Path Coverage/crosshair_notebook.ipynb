# %% [markdown]
# # CrossHair Path Coverage

# %%
from pathlib import Path
import subprocess, sys
ROOT=Path.cwd()
RUNNER=ROOT/'run_crosshair.py'
REPO=ROOT.parent/'Cyclomatic Complexity'/'tool_examples'

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'cover', 'logic_examples.route_order'], cwd=ROOT, check=True)
