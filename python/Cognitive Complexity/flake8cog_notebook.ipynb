# %% [markdown]
# # flake8-cognitive-complexity Tool Runner

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
RUNNER = ROOT / "run_flake8cog.py"
REPO = ROOT.parent / "github-actions-cicd-example"
TARGET = REPO / "actionscicd" / "somecode.py"

def run_command(args):
    result = subprocess.run(args, cwd=ROOT, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr, file=sys.stderr)
    if result.returncode != 0 and result.returncode != 1:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")
    return result.returncode

# %%
run_command([sys.executable, str(RUNNER), "install"])
# Out:
# Requirement already satisfied: flake8 in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 1)) (7.3.0)
# Requirement already satisfied: flake8-cognitive-complexity in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from -r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from flake8->-r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from flake8->-r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from flake8->-r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: setuptools in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from flake8-cognitive-complexity->-r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 2)) (82.0.1)
# Requirement already satisfied: cognitive_complexity in d:\projects\metrics_derived\python\cognitive complexity\tools\flake8cog\.venv\lib\site-packages (from flake8-cognitive-complexity->-r D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\requirements.txt (line 2)) (1.3.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: D:\Projects\Metrics_derived\python\Cognitive Complexity\tools\flake8cog\.venv\Scripts\python.exe -m pip install --upgrade pip
# 0

# %%
run_command([sys.executable, str(RUNNER), "run", "--repo", str(REPO), "--", "--extend-ignore=E501", "--max-cognitive-complexity=1", str(TARGET)])
# Out:
# d:\Projects\Metrics_derived\python\github-actions-cicd-example\actionscicd\somecode.py:0:1: E902 FileNotFoundError: [Errno 2] No such file or directory: 'd:\\Projects\\Metrics_derived\\python\\github-actions-cicd-example\\actionscicd\\somecode.py'
# 1

# %%
from pathlib import Path
report = Path(r'requirements-whitebox.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# -r tools/complexipy/requirements.txt
# -r tools/flake8cog/requirements.txt
# -r tools/pyrefact/requirements.txt
