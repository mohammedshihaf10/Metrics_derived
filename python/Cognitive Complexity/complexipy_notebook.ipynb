# %% [markdown]
# # complexipy Tool Runner
#
# This notebook uses the existing `run_complexipy.py` script.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
RUNNER = ROOT / "run_complexipy.py"
REPO = ROOT.parent / "github-actions-cicd-example"
TARGET = REPO / "actionscicd" / "somecode.py"

def run_command(args):
    result = subprocess.run(args, cwd=ROOT, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr, file=sys.stderr)
    if result.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")
    return result.returncode

# %%
run_command([sys.executable, str(RUNNER), "install"])

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(REPO),
    "--",
    str(TARGET),
    "--ignore-complexity",
    "--sort",
    "desc",
    "--color",
    "no",
])
# Out:
# --------------------------------- complexipy ----------------------------------
# somecode.py
#     load_datafile 5 PASSED
#     add_arrays 0 PASSED
#     unused_fn 0 PASSED
#
# All functions are within the allowed complexity.
# ----------------------------- Analysis completed! -----------------------------

# %%
run_command([
    sys.executable,
    str(RUNNER),
    "run",
    "--repo",
    str(REPO),
    "--",
    str(TARGET),
    "--ignore-complexity",
    "--sort",
    "desc",
    "--output-json",
    "--color",
    "no",
])
# Out:
# [
#   {
#     "complexity": 0,
#     "file_name": "somecode.py",
#     "function_name": "add_arrays",
#     "path": "somecode.py"
#   },
#   {
#     "complexity": 0,
#     "file_name": "somecode.py",
#     "function_name": "unused_fn",
#     "path": "somecode.py"
#   },
#   {
#     "complexity": 5,
#     "file_name": "somecode.py",
#     "function_name": "load_datafile",
#     "path": "somecode.py"
#   }
# ]

# %%
from pathlib import Path
report = Path(r'requirements-whitebox.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# -r tools/complexipy/requirements.txt
# -r tools/flake8cog/requirements.txt
# -r tools/pyrefact/requirements.txt
