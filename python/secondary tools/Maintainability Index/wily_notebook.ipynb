# %% [markdown]
# # wily Maintainability Index

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_wily.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Maintainability Index\\run_wily.py', 'install'], returncode=0)

# %%
result = subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'rank', 'actionscicd', 'maintainability.mi'], cwd=ROOT)
print(f'wily exit code: {result.returncode}')
# Out:
# wily exit code: 0

# %%
print((ROOT / 'wily_report.txt').exists())
# Out:
# True

# %%
from pathlib import Path
report = Path(r'requirements-whitebox.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# ﻿wily
