# %% [markdown]
# # copydetect Code Duplication

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_copydetect.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Code Duplication\\run_copydetect.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', '-t', '.', '-e', 'py'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Code Duplication\\run_copydetect.py', 'run', '--repo', 'D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example', '--', '-t', '.', '-e', 'py'], returncode=0)

# %%
print((ROOT / 'copydetect_report.html').exists())
# Out:
# True

# %%
from pathlib import Path
report = Path(r'copydetect_report.html')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
#   0.00: Generating file fingerprints
#   0.15: Beginning code comparison
#   0.15: Code comparison completed
# Output saved to ./report.html
