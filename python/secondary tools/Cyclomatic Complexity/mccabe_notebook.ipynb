# %% [markdown]
# # mccabe Cyclomatic Complexity

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_mccabe.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Cyclomatic Complexity\\run_mccabe.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', '--min', '1', 'actionscicd/somecode.py'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Cyclomatic Complexity\\run_mccabe.py', 'run', '--repo', 'D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example', '--', '--min', '1', 'actionscicd/somecode.py'], returncode=0)

# %%
print((ROOT / 'mccabe_report.txt').read_text(encoding='utf-8'))
# Out:
# 9:0: 'add_arrays' 1
# 15:0: 'load_datafile' 3
# 32:0: 'unused_fn' 1

# %%
from pathlib import Path
report = Path(r'mccabe_report.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# 9:0: 'add_arrays' 1
# 15:0: 'load_datafile' 3
# 32:0: 'unused_fn' 1
