# %% [markdown]
# # git log Code Churn

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_git_churn.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Code Churn\\run_git_churn.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO)], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Code Churn\\run_git_churn.py', 'run', '--repo', 'D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example'], returncode=0)

# %%
print(json.loads((ROOT / 'git_churn_report.json').read_text(encoding='utf-8'))['summary'])
# Out:
# {'total_files_touched': 29, 'total_commits': 1}

# %%
from pathlib import Path
report = Path(r'git_churn_report.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# {
#   "summary": {
#     "total_files_touched": 29,
#     "total_commits": 1
#   },
#   "top_files": [
#     {
#       "path": ".gitignore",
#       "commit_count": 1,
#       "added_lines": 140,
#       "deleted_lines": 0,
#       "total_churn": 140
#     },
#     {
#       "path": "README.md",
#       "commit_count": 2,
#       "added_lines": 67,
#       "deleted_lines": 0,
#       "total_churn": 67
#     },
#     {
#       "path": ".github/workflows/5_docs_deploy.yml",
#       "commit_count": 1,
#       "added_lines": 60,
#       "deleted_lines": 0,
#       "total_churn": 60
#     },
#     {
#       "path": "docs/source/conf.py",
#       "commit_count": 1,
#       "added_lines": 59,
#       "deleted_lines": 0,
#       "total_churn": 59
#     },
#     {
#       "path": ".github/workflows/2_coverage.yml",
#       "commit_count": 1,
#       "added_lines": 52,
#       "deleted_lines": 0,
#       "total_churn": 52
#     },
#     {
#       "path": ".github/workflows/3_linting.yml",
#       "commit_count": 1,
#       "added_lines": 48,
#       "deleted_lines": 0,
#       "total_churn": 48
#     },
#     {
#       "path": ".github/workflows/6_pypi_release.yml",
#       "commit_count": 1,
#       "added_lines": 44,
#       "deleted_lines": 0,
#       "total_churn": 44
#     },
#     {
#       "path": ".github/workflows/1_tests.yml",
#       "commit_count": 1,
#       "added_lines": 40,
#       "deleted_lines": 0,
#       "total_churn": 40
#     },
#     {
#       "path": ".github/workflows/4_docs_build.yml",
#       "commit_count": 1,
#       "added_lines": 40,
#       "deleted_lines": 0,
#       "total_churn": 40
#     },
#     {
#       "path": "setup.cfg",
#       "commit_count": 1,
#       "added_lines": 40,
#       "deleted_lines": 0,
#       "total_churn": 40
#     }
#   ]
# }
