# %% [markdown]
# # coverage.py + ast paths Path Coverage

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_path_combo.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Path Coverage\\run_path_combo.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO)], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Path Coverage\\run_path_combo.py', 'run', '--repo', 'D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example'], returncode=0)

# %%
print(json.loads((ROOT / 'path_coverage_report.json').read_text(encoding='utf-8'))['estimated_total_paths'])
# Out:
# 3

# %%
from pathlib import Path
report = Path(r'path_coverage_report.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# {
#   "file": "D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example\\actionscicd\\somecode.py",
#   "covered_lines": [
#     4,
#     5,
#     6,
#     9,
#     12,
#     15,
#     18,
#     19,
#     21,
#     22,
#     23,
#     24,
#     25,
#     26,
#     27,
#     29,
#     32
#   ],
#   "functions": [
#     {
#       "name": "add_arrays",
#       "lineno": 9,
#       "estimated_paths": 1,
#       "covered": true
#     },
#     {
#       "name": "load_datafile",
#       "lineno": 15,
#       "estimated_paths": 1,
#       "covered": true
#     },
#     {
#       "name": "unused_fn",
#       "lineno": 32,
#       "estimated_paths": 1,
#       "covered": true
#     }
#   ],
#   "covered_functions": 3,
#   "estimated_total_paths": 3
# }
