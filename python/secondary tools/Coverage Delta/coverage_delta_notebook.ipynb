# %% [markdown]
# # coverage.py + git diff Coverage Delta

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_diff_cover.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Coverage Delta\\run_diff_cover.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'HEAD~1'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Coverage Delta\\run_diff_cover.py', 'run', '--repo', 'D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example', '--', 'HEAD~1'], returncode=0)

# %%
print(json.loads((ROOT / 'coverage_delta_secondary.json').read_text(encoding='utf-8'))['coverage_percent'])
# Out:
# 100.0

# %%
from pathlib import Path
report = Path(r'coverage_delta_secondary.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# {
#   "compare_ref": "HEAD~1",
#   "changed_lines": 0,
#   "covered_changed_lines": 0,
#   "uncovered_changed_lines": 0,
#   "coverage_percent": 100.0,
#   "covered": [],
#   "uncovered": []
# }
