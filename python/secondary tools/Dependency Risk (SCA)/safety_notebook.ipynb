# %% [markdown]
# # safety Dependency Risk

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_safety.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Dependency Risk (SCA)\\run_safety.py', 'install'], returncode=0)

# %%
result = subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'check', '--json'], cwd=ROOT)
print(f'safety exit code: {result.returncode}')
# Out:
# safety exit code: 0

# %%
print((ROOT / 'safety_report.json').exists())
# Out:
# True

# %%
from pathlib import Path
report = Path(r'safety_report.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# +===========================================================================================================================================================================================+
#
#
# DEPRECATED: this command (`check`) has been DEPRECATED, and will be unsupported beyond 01 June 2024.
#
#
# We highly encourage switching to the new `scan` command which is easier to use, more powerful, and can be set up to mimic the deprecated command if required.
#
#
# +===========================================================================================================================================================================================+
#
#
# {
#     "report_meta": {
#         "scan_target": "environment",
#         "scanned": [
#             "D:\\Projects\\Metrics_derived\\python\\secondary tools\\Dependency Risk (SCA)\\tools\\safety\\.venv\\Lib\\site-packages"
#         ],
#         "scanned_full_path": [
# ...
