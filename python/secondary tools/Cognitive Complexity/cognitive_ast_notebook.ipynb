# %% [markdown]
# # cognitive-ast Cognitive Complexity

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_cognitive_ast.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Cognitive Complexity\\run_cognitive_ast.py', 'install'], returncode=0)

# %%
subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO)], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Cognitive Complexity\\run_cognitive_ast.py', 'run', '--repo', 'D:\\Projects\\Metrics_derived\\python\\secondary tools\\github-actions-cicd-example'], returncode=0)

# %%
print(len(json.loads((ROOT / 'cognitive_ast_report.json').read_text(encoding='utf-8'))['files']))
# Out:
# 1

# %%
from pathlib import Path
report = Path(r'cognitive_ast_report.json')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# {
#   "files": [
#     {
#       "file": "actionscicd\\somecode.py",
#       "functions": [
#         {
#           "name": "add_arrays",
#           "lineno": 9,
#           "cognitive_complexity": 0
#         },
#         {
#           "name": "load_datafile",
#           "lineno": 15,
#           "cognitive_complexity": 0
#         },
#         {
#           "name": "unused_fn",
#           "lineno": 32,
#           "cognitive_complexity": 0
#         }
#       ]
#     }
#   ]
# }
