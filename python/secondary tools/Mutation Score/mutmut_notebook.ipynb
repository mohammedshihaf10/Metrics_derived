# %% [markdown]
# # mutmut Mutation Score

# %%
from pathlib import Path
import subprocess, sys, json
ROOT = Path.cwd()
RUNNER = ROOT / 'run_mutmut.py'
REPO = (ROOT.parent / "github-actions-cicd-example").resolve()

# %%
subprocess.run([sys.executable, str(RUNNER), 'install'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['D:\\Projects\\Metrics_derived\\python\\Cyclomatic Complexity\\tools\\coveragepy\\.venv\\Scripts\\python.exe', 'd:\\Projects\\Metrics_derived\\python\\secondary tools\\Mutation Score\\run_mutmut.py', 'install'], returncode=0)

# %%
result = subprocess.run([sys.executable, str(RUNNER), 'run', '--repo', str(REPO), '--', 'run'], cwd=ROOT)
print(f'mutmut exit code: {result.returncode}')
# Out:
# mutmut exit code: 1

# %%
print('mutmut run completed')
# Out:
# mutmut run completed

# %%
from pathlib import Path
report = Path(r'mutmut_report.txt')
print(report.read_text(encoding='utf-8', errors='ignore'))
# Out:
# To run mutmut on Windows, please use the WSL. Native windows support is tracked in issue https://github.com/boxed/mutmut/issues/397
